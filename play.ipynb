# %%
import torch
from solver import Optimus

train_pth = ('data/processed_data/train_x.npy', 'data/processed_data/train_y.npy')
test_pth = ('data/processed_data/test_x.npy', 'data/processed_data/test_y.npy')
vocab = '*abcdefghijklmnopqrstuvwxyz_'

state_dict_pth = 'model/bigger/model_statedict.pth'

data_scale = 2

block_size = 32  #T
batch_size = 256*data_scale #B
embed_size = 512 #C

vocab_size = 28
n_head = 16
n_layer = 12
output_size = 26

dropout = 0

device = torch.device('cpu')

solver = Optimus(state_dict_pth, vocab, vocab_size, embed_size, block_size, n_head, n_layer, output_size, dropout, device)
# Out:
# /Users/shivampandey/projects/hangman_final/solver.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
from hangman import Hangman
game = Hangman('data/split_data/test.txt', solver)

# %%
game.play(250)
# Out:
# Starting Game 1
# You have 6 tries
# ___________ , Tries left 6
# e
# ___e___e___ , Tries left 6
# n
# ___e___e___ , Tries left 5
# r
# ___er__e___ , Tries left 5
# i
# ___er__e___ , Tries left 4
# a
# ___era_e___ , Tries left 4
# c
# c__erace___ , Tries left 4
# s
# c__erace__s , Tries left 4
# o
# c__eraceo_s , Tries left 4
# u
# c__eraceous , Tries left 4
# h
# c__eraceous , Tries left 3
# l
# c__eraceous , Tries left 2
# y
# cy_eraceous , Tries left 2
# p
# Won! Answer: cyperaceous
# Starting Game 2
# You have 6 tries
# _________ , Tries left 6
# e
# _______e_ , Tries left 6
# s
# ______se_ , Tries left 6
# d
# d_____sed , Tries left 6
# i
# d_____sed , Tries left 5
# o
# d_____sed , Tries left 4
# a
# d_____sed , Tries left 3
# u
# d___u_sed , Tries left 3
# r
# dr__ursed , Tries left 3
# y
# dry_ursed , Tries left 3
# b
# dry_ursed , Tries left 2
# t
# dry_ursed , Tries left 1
# c
# Game Over! Answer: drynursed, Your Guess: dry_ursed
# Starting Game 3
# You have 6 tries
# ...
